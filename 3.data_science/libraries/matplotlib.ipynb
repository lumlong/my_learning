# %% [markdown]
# # Setup

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Quick Start

# %% [markdown]
# <!-- ![Figures Anatomy](./images/matplotlib_anatomy.jpg) -->
#
# <img src="../images/matplotlib_anatomy.jpg"  width="600">

# %% [markdown]
# ## Plot a figure

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')
# Out:
# Text(0.5, 1.0, 'Simple plot')

# %% [markdown]
# ## Plot more data on a figure

# %%
# More data
x2 = np.linspace(0, 2*np.pi, 400)
y2 = np.cos(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
# Plot data on the same figure
ax.scatter(x2, y2, c='g', s=1)
ax.set_title('Simple plot')
# Out:
# Text(0.5, 1.0, 'Simple plot')

# %% [markdown]
# ## Working with multiple Figures and Axes

# %%
# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# Create four polar axes and access them through the returned array
fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)

# Share both X and Y axes with all subplots
plt.subplots(2, 2, sharex='all', sharey='all')

# Create figure number 10 with a single subplot
# and clears it if it already exists.
fig, ax = plt.subplots(num=10, clear=True)

# %% [markdown]
# ## Loop through figures

# %%
nrow = 2
ncol = 3

fig, axs = plt.subplots(nrow, ncol, sharey=True)

for i, ax in enumerate(fig.axes):
    ax.plot(x, y)
    ax.set_title(f'axe {i}')
    
fig.tight_layout()
plt.show()
